# %% [markdown]
# Wikidata and Bandford low analysis

# %% [markdown]
# https://linkedwiki.com/query/wikidata_Country_populations_together_with_total_city_populations?lang=EN
#
# and Benford law :
# https://towardsdatascience.com/frawd-detection-using-benfords-law-python-code-9db8db474cf8

# %%
import pandas as pd
import numpy as np
import math


from SPARQLWrapper import SPARQLWrapper, JSON
from SPARQLWrapper import SPARQLWrapper2

sparql = SPARQLWrapper("https://query.wikidata.org/sparql")

strSparqlSelect = ("""
PREFIX bd: <http://www.bigdata.com/rdf#>
PREFIX wd: <http://www.wikidata.org/entity/>
PREFIX wdt: <http://www.wikidata.org/prop/direct/>
PREFIX wikibase: <http://wikiba.se/ontology#>

SELECT ?country ?countryLabel ?continentLabel ?population ?hdindex ?totalCityPopulation (?population / ?totalCityPopulation AS ?ratio) {
  # ?country wdt:P1082 ?population .
  # ?country wdt:P30  ?continent .
  # ?continent wdt:P31 wd:Q5107 .
  # ?country   wdt:P1081 ?hdindex
  
   FILTER NOT EXISTS {
    # ?country wd:P1082/wdt:P585 ?hdi_date_ .
    FILTER (?hdi_date_ > ?hdi_date)
                     }
   FILTER NOT EXISTS {
    # ?country wdt:P1081/wdt:P585 ?hdi_date_ .
    FILTER (?hdi_date_ > ?hdi_date)
                      }
 
  
  
  SERVICE wikibase:label { bd:serviceParam wikibase:language "en" }
  {
    SELECT ?country (SUM(?cityPopulation) AS ?totalCityPopulation) WHERE {
      # ?city wdt:P31 wd:Q515 .
      # ?city wdt:P17 ?country .
      # ?city wdt:P1082 ?cityPopulation .
      
    } GROUP BY ?country
  }
} ORDER BY ?ratio""")

sparql.setQuery(strSparqlSelect)
try:

  sparql.setReturnFormat(JSON)
  results = sparql.query().convert()
  # results = sparql.queryAndConvert()

  for result in results["results"]["bindings"]:
      print(result)
      # print(result["label"]["value"])


except Exception as e:
  print(e)
# Out:
# {'country': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q977'}, 'hdindex': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '0.509'}, 'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '956985'}, 'totalCityPopulation': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '2863922'}, 'countryLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Djibouti'}, 'continentLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Africa'}, 'ratio': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '0.33415190776843782757'}}
# {'country': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q1039'}, 'hdindex': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '0.618'}, 'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '204327'}, 'totalCityPopulation': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '391964'}, 'countryLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'São Tomé and Príncipe'}, 'continentLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Africa'}, 'ratio': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '0.52129022053045687869'}}
# {'country': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q664'}, 'hdindex': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '0.937'}, 'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '5118700'}, 'totalCityPopulation': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '7145560'}, 'countryLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'New Zealand'}, 'continentLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Insular Oceania'}, 'ratio': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '0.71634693432005329183'}}
# {'country': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q878'}, 'hdindex': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '0.911'}, 'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '9890400'}, 'totalCityPopulation': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '12009189'}, 'countryLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'United Arab Emirates'}, 'continentLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Asia'}, 'ratio': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '0.82356935176888297786'}}
# {'country': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q221'}, 'hdindex': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '0.77'}, 'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '1836713'}, 'totalCityPopulation': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '2051544'}, 'countryLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'North Macedonia'}, 'continentLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Europe'}, 'ratio': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '0.89528325982772000016'}}
# {'country': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q1011'}, 'hdindex': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '0.662'}, 'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '555988'}, 'totalCityPopulation': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '556778'}, 'countryLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Cape Verde'}, 'continentLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Africa'}, 'ratio': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '0.99858112209893350671'}}
# {'country': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q334'}, 'hdindex': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '0.939'}, 'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '5866139'}, 'totalCityPopulation': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '5866139'}, 'countryLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Singapore'}, 'continentLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Asia'}, 'ratio': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '1'}}
# {'country': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q25279'}, 'hdindex': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '0.89'}, 'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '160337'}, 'totalCityPopulation': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '150000'}, 'countryLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Curaçao'}, 'continentLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'South America'}, 'ratio': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '1.06891333333333333333'}}
# {'country': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q408'}, 'hdindex': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '0.951'}, 'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '24511800'}, 'totalCityPopulation': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '20035891'}, 'countryLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Australia'}, 'continentLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Insular Oceania'}, 'ratio': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '1.2233945572972023056'}}
# {'country': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q778'}, 'hdindex': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '0.812'}, 'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '395361'}, 'totalCityPopulation': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '320345'}, 'countryLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'The Bahamas'}, 'continentLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'North America'}, 'ratio': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '1.23417253273814169099'}}
# {'country': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q717'}, 'hdindex': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '0.691'}, 'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '28515829'}, 'totalCityPopulation': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '22409286'}, 'countryLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Venezuela'}, 'continentLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'South America'}, 'ratio': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '1.27250056070505771581'}}
# {'country': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q1007'}, 'hdindex': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '0.483'}, 'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '1861283'}, 'totalCityPopulation': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '1446859'}, 'countryLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Guinea-Bissau'}, 'continentLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Africa'}, 'ratio': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '1.28643012207823982848'}}
# {'country': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q189'}, 'hdindex': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '0.959'}, 'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '364260'}, 'totalCityPopulation': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '281711'}, 'countryLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Iceland'}, 'continentLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Europe'}, 'ratio': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '1.29302725133203886252'}}
# {'country': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q711'}, 'hdindex': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '0.739'}, 'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '3075647'}, 'totalCityPopulation': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '2370308'}, 'countryLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Mongolia'}, 'continentLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Asia'}, 'ratio': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '1.29757272050720834592'}}
# {'country': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q865'}, 'hdindex': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '0.911'}, 'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '23593794'}, 'totalCityPopulation': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '18115941'}, 'countryLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Taiwan'}, 'continentLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Asia'}, 'ratio': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '1.30237750277504215762'}}
# {'country': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q781'}, 'hdindex': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '0.788'}, 'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '95425'}, 'totalCityPopulation': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '70123'}, 'countryLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Antigua and Barbuda'}, 'continentLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'North America'}, 'ratio': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '1.36082312508021619155'}}
# {'country': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q810'}, 'hdindex': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '0.72'}, 'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '10428241'}, 'totalCityPopulation': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '7634215'}, 'countryLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Jordan'}, 'continentLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Asia'}, 'ratio': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '1.36598733465064842947'}}
# {'country': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q801'}, 'hdindex': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '0.919'}, 'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '9187000'}, 'totalCityPopulation': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '6557641'}, 'countryLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Israel'}, 'continentLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Asia'}, 'ratio': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '1.40096110781300775691'}}
# {'country': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q33'}, 'hdindex': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '0.94'}, 'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '5516224'}, 'totalCityPopulation': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '3889389'}, 'countryLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Finland'}, 'continentLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Europe'}, 'ratio': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '1.4182752098080186888'}}
# {'country': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q983'}, 'hdindex': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '0.596'}, 'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '1267689'}, 'totalCityPopulation': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '888148'}, 'countryLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Equatorial Guinea'}, 'continentLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Africa'}, 'ratio': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '1.42733981273391371708'}}
# {'country': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q77'}, 'hdindex': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '0.809'}, 'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '3456750'}, 'totalCityPopulation': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '2376896'}, 'countryLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Uruguay'}, 'continentLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'South America'}, 'ratio': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '1.45431268343251029915'}}
# {'country': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q419'}, 'hdindex': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '0.762'}, 'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '29381884'}, 'totalCityPopulation': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '19219901'}, 'countryLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Peru'}, 'continentLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'South America'}, 'ratio': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '1.52872192213685179752'}}
# {'country': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q37'}, 'hdindex': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '0.875'}, 'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '2790842'}, 'totalCityPopulation': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '1817374'}, 'countryLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Lithuania'}, 'continentLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Europe'}, 'ratio': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '1.53564538724555319929'}}
# {'country': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q817'}, 'hdindex': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '0.831'}, 'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '4600000'}, 'totalCityPopulation': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '2989000'}, 'countryLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Kuwait'}, 'continentLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Asia'}, 'ratio': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '1.53897624623619939779'}}
# {'country': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q750'}, 'hdindex': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '0.692'}, 'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '11051600'}, 'totalCityPopulation': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '6588012'}, 'countryLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Bolivia'}, 'continentLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'South America'}, 'ratio': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '1.67753185634755977979'}}
# {'country': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q230'}, 'hdindex': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '0.802'}, 'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '3717100'}, 'totalCityPopulation': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '2196069.605'}, 'countryLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Georgia'}, 'continentLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Europe'}, 'ratio': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '1.69261483859023676073'}}
# {'country': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q230'}, 'hdindex': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '0.802'}, 'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '3717100'}, 'totalCityPopulation': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '2196069.605'}, 'countryLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Georgia'}, 'continentLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Asia'}, 'ratio': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '1.69261483859023676073'}}
# {'country': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q710'}, 'hdindex': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '0.624'}, 'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '119438'}, 'totalCityPopulation': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '69512'}, 'countryLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Kiribati'}, 'continentLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Insular Oceania'}, 'ratio': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '1.71823570031073771435'}}
# {'country': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q236'}, 'hdindex': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '0.832'}, 'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '622359'}, 'totalCityPopulation': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '359308'}, 'countryLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Montenegro'}, 'continentLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Europe'}, 'ratio': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '1.73210448974139178643'}}
# {'country': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q222'}, 'hdindex': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '0.796'}, 'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '2793592'}, 'totalCityPopulation': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '1544726'}, 'countryLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Albania'}, 'continentLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Europe'}, 'ratio': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '1.80847088739362191094'}}
# {'country': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q32'}, 'hdindex': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '0.93'}, 'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '645397'}, 'totalCityPopulation': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '348346'}, 'countryLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Luxembourg'}, 'continentLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Europe'}, 'ratio': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '1.85274698144947839217'}}
# {'country': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q217'}, 'hdindex': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '0.767'}, 'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '2550900'}, 'totalCityPopulation': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '1372143'}, 'countryLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Moldova'}, 'continentLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Europe'}, 'ratio': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '1.8590627944755029177'}}
# {'country': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q232'}, 'hdindex': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '0.811'}, 'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '18276500'}, 'totalCityPopulation': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '9800394'}, 'countryLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Kazakhstan'}, 'continentLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Europe'}, 'ratio': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '1.86487400404514349117'}}
# {'country': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q232'}, 'hdindex': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '0.811'}, 'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '18276500'}, 'totalCityPopulation': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '9800394'}, 'countryLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Kazakhstan'}, 'continentLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Asia'}, 'ratio': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '1.86487400404514349117'}}
# {'country': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q971'}, 'hdindex': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '0.571'}, 'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '5260750'}, 'totalCityPopulation': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '2733459'}, 'countryLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Republic of the Congo'}, 'continentLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Africa'}, 'ratio': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '1.92457615058429630735'}}
# {'country': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q672'}, 'hdindex': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '0.641'}, 'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '11792'}, 'totalCityPopulation': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '6025'}, 'countryLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Tuvalu'}, 'continentLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Insular Oceania'}, 'ratio': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '1.95717842323651452282'}}
# {'country': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q786'}, 'hdindex': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '0.767'}, 'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '10403761'}, 'totalCityPopulation': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '5312560'}, 'countryLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Dominican Republic'}, 'continentLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'North America'}, 'ratio': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '1.95833289412260755643'}}
# {'country': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q858'}, 'hdindex': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '0.577'}, 'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '18499181'}, 'totalCityPopulation': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '8931980'}, 'countryLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Syria'}, 'continentLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Asia'}, 'ratio': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '2.07111760214420542814'}}
# {'country': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q43'}, 'hdindex': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '0.838'}, 'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '84680273'}, 'totalCityPopulation': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '40725414.408'}, 'countryLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Turkey'}, 'continentLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Europe'}, 'ratio': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '2.07929800668561437515'}}
# {'country': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q43'}, 'hdindex': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '0.838'}, 'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '84680273'}, 'totalCityPopulation': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '40725414.408'}, 'countryLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Turkey'}, 'continentLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Asia'}, 'ratio': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '2.07929800668561437515'}}
# {'country': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q784'}, 'hdindex': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '0.72'}, 'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '73925'}, 'totalCityPopulation': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '34940'}, 'countryLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Dominica'}, 'continentLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'North America'}, 'ratio': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '2.11576989124212936463'}}
# {'country': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q1016'}, 'hdindex': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '0.718'}, 'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '6678567'}, 'totalCityPopulation': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '3065287'}, 'countryLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Libya'}, 'continentLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Africa'}, 'ratio': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '2.17877379834253693047'}}
# {'country': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q695'}, 'hdindex': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '0.767'}, 'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '21729'}, 'totalCityPopulation': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '9935'}, 'countryLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Palau'}, 'continentLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Insular Oceania'}, 'ratio': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '2.18711625566180171112'}}
# {'country': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q783'}, 'hdindex': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '0.621'}, 'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '9265067'}, 'totalCityPopulation': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '4222399.794'}, 'countryLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Honduras'}, 'continentLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'North America'}, 'ratio': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '2.19426569060693734962'}}
# {'country': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q241'}, 'hdindex': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '0.764'}, 'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '11181595'}, 'totalCityPopulation': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '5073957'}, 'countryLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Cuba'}, 'continentLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'North America'}, 'ratio': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '2.20372285378058978427'}}
# {'country': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q16'}, 'hdindex': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '0.936'}, 'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '36991981'}, 'totalCityPopulation': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '15409859'}, 'countryLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Canada'}, 'continentLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'North America'}, 'ratio': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '2.40053987515395176555'}}
# {'country': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q215'}, 'hdindex': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '0.918'}, 'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '2066880'}, 'totalCityPopulation': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '853954'}, 'countryLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Slovenia'}, 'continentLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Europe'}, 'ratio': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '2.42036456296240781119'}}
# {'country': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q730'}, 'hdindex': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '0.73'}, 'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '563402'}, 'totalCityPopulation': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '229257'}, 'countryLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Suriname'}, 'continentLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'South America'}, 'ratio': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '2.45751274770236023328'}}
# {'country': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q766'}, 'hdindex': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '0.709'}, 'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '2890299'}, 'totalCityPopulation': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '1141944'}, 'countryLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Jamaica'}, 'continentLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'North America'}, 'ratio': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '2.53103392110296126605'}}
# {'country': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q1000'}, 'hdindex': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '0.706'}, 'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '2025137'}, 'totalCityPopulation': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '797003'}, 'countryLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Gabon'}, 'continentLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Africa'}, 'ratio': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '2.54094024740182910227'}}
# {'country': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q403'}, 'hdindex': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '0.802'}, 'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '7022268'}, 'totalCityPopulation': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '2752173'}, 'countryLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Serbia'}, 'continentLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Europe'}, 'ratio': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '2.5515358227843961844'}}
# {'country': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q414'}, 'hdindex': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '0.842'}, 'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '47327407'}, 'totalCityPopulation': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '18536206'}, 'countryLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Argentina'}, 'continentLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'South America'}, 'ratio': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '2.55324131594135283132'}}
# {'country': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q760'}, 'hdindex': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '0.715'}, 'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '178844'}, 'totalCityPopulation': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '70000'}, 'countryLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Saint Lucia'}, 'continentLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'North America'}, 'ratio': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '2.55491428571428571429'}}
# {'country': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q244'}, 'hdindex': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '0.79'}, 'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '285719'}, 'totalCityPopulation': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '110000'}, 'countryLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Barbados'}, 'continentLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'North America'}, 'ratio': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '2.59744545454545454545'}}
# {'country': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q736'}, 'hdindex': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '0.74'}, 'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '18000062'}, 'totalCityPopulation': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '6844212'}, 'countryLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Ecuador'}, 'continentLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'South America'}, 'ratio': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '2.6299685047745452654'}}
# {'country': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q1050'}, 'hdindex': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '0.597'}, 'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '1124753'}, 'totalCityPopulation': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '426106'}, 'countryLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Eswatini'}, 'continentLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Africa'}, 'ratio': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '2.63960845423439238124'}}
# {'country': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q20'}, 'hdindex': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '0.961'}, 'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '5425270'}, 'totalCityPopulation': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '2011592'}, 'countryLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Norway'}, 'continentLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Europe'}, 'ratio': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '2.69700316962883129382'}}
# {'country': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q986'}, 'hdindex': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '0.492'}, 'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '3497000'}, 'totalCityPopulation': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '1287797'}, 'countryLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Eritrea'}, 'continentLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Africa'}, 'ratio': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '2.71549009665343217914'}}
# {'country': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q874'}, 'hdindex': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '0.745'}, 'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '5850901'}, 'totalCityPopulation': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '2141264'}, 'countryLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Turkmenistan'}, 'continentLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Asia'}, 'ratio': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '2.73245195361244573299'}}
# {'country': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q804'}, 'hdindex': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '0.805'}, 'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '4098587'}, 'totalCityPopulation': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '1479264'}, 'countryLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Panama'}, 'continentLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'South America'}, 'ratio': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '2.77069339887944274991'}}
# {'country': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q804'}, 'hdindex': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '0.805'}, 'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '4098587'}, 'totalCityPopulation': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '1479264'}, 'countryLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Panama'}, 'continentLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'North America'}, 'ratio': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '2.77069339887944274991'}}
# {'country': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q884'}, 'hdindex': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '0.925'}, 'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '51466201'}, 'totalCityPopulation': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '18294978'}, 'countryLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'South Korea'}, 'continentLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Asia'}, 'ratio': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '2.81313270778461717746'}}
# {'country': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q145'}, 'hdindex': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '0.929'}, 'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '66022273'}, 'totalCityPopulation': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '23418603'}, 'countryLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'United Kingdom'}, 'continentLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Europe'}, 'ratio': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '2.81922337553610691466'}}
# {'country': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q219060'}, 'hdindex': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '0.715'}, 'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '5227193'}, 'totalCityPopulation': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '1852745'}, 'countryLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'State of Palestine'}, 'continentLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Asia'}, 'ratio': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '2.82132349567803448397'}}
# {'country': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q79'}, 'hdindex': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '0.731'}, 'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '94798827'}, 'totalCityPopulation': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '33411500'}, 'countryLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Egypt'}, 'continentLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Africa'}, 'ratio': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '2.83731131496640378313'}}
# {'country': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q79'}, 'hdindex': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '0.731'}, 'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '94798827'}, 'totalCityPopulation': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '33411500'}, 'countryLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Egypt'}, 'continentLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Asia'}, 'ratio': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '2.83731131496640378313'}}
# {'country': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q96'}, 'hdindex': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '0.758'}, 'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '124777324'}, 'totalCityPopulation': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '43648437'}, 'countryLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Mexico'}, 'continentLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'North America'}, 'ratio': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '2.85868939591124419873'}}
# {'country': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q945'}, 'hdindex': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '0.539'}, 'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '7797694'}, 'totalCityPopulation': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '2719117'}, 'countryLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Togo'}, 'continentLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Africa'}, 'ratio': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '2.86773022271568306917'}}
# {'country': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q734'}, 'hdindex': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '0.714'}, 'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '777859'}, 'totalCityPopulation': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '265653'}, 'countryLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Guyana'}, 'continentLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'South America'}, 'ratio': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '2.92810169657410230639'}}
# ...
# {'country': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q399'}, 'hdindex': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '0.759'}, 'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '2930450'}, 'totalCityPopulation': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '123683'}, 'countryLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Armenia'}, 'continentLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Asia'}, 'ratio': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '23.69323189120574371579'}}
# {'country': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q851'}, 'hdindex': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '0.875'}, 'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '33000000'}, 'totalCityPopulation': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '1344776'}, 'countryLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Saudi Arabia'}, 'continentLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Asia'}, 'ratio': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '24.53940284478604615192'}}
# {'country': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q1037'}, 'hdindex': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '0.534'}, 'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '12208407'}, 'totalCityPopulation': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '487080'}, 'countryLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Rwanda'}, 'continentLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Africa'}, 'ratio': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '25.06448016752894801675'}}
# {'country': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q142'}, 'hdindex': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '0.903'}, 'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '67063703'}, 'totalCityPopulation': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '2520211'}, 'countryLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'France'}, 'continentLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Europe'}, 'ratio': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '26.61035246651966839284'}}
# {'country': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q846'}, 'hdindex': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '0.855'}, 'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '2639211'}, 'totalCityPopulation': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '87970'}, 'countryLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Qatar'}, 'continentLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Asia'}, 'ratio': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '30.00126179379333863817'}}
# {'country': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q115'}, 'hdindex': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '0.498'}, 'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '104957438'}, 'totalCityPopulation': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '3158391'}, 'countryLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Ethiopia'}, 'continentLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Africa'}, 'ratio': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '33.23129973458004407941'}}
# {'country': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q229'}, 'hdindex': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '0.896'}, 'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '1141166'}, 'totalCityPopulation': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '33207'}, 'countryLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Cyprus'}, 'continentLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Europe'}, 'ratio': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '34.36522419971692715391'}}
# {'country': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q229'}, 'hdindex': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '0.896'}, 'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '1141166'}, 'totalCityPopulation': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '33207'}, 'countryLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Cyprus'}, 'continentLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Asia'}, 'ratio': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '34.36522419971692715391'}}
# {'country': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q17'}, 'hdindex': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '0.925'}, 'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '125440000'}, 'totalCityPopulation': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '3096335'}, 'countryLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Japan'}, 'continentLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Asia'}, 'ratio': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '40.51241225513389216606'}}
# {'country': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q1019'}, 'hdindex': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '0.501'}, 'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '25570895'}, 'totalCityPopulation': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '580888'}, 'countryLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Madagascar'}, 'continentLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Africa'}, 'ratio': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '44.02035332112214402776'}}
# {'country': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q691'}, 'hdindex': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '0.558'}, 'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '8935000'}, 'totalCityPopulation': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '198632'}, 'countryLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Papua New Guinea'}, 'continentLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Insular Oceania'}, 'ratio': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '44.98268154174553949011'}}
# {'country': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q948'}, 'hdindex': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '0.731'}, 'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '11565204'}, 'totalCityPopulation': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '171627'}, 'countryLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Tunisia'}, 'continentLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Africa'}, 'ratio': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '67.38569106259504623398'}}
# {'country': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q159'}, 'hdindex': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '0.822'}, 'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '146804372'}, 'totalCityPopulation': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '2097531'}, 'countryLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Russia'}, 'continentLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Europe'}, 'ratio': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '69.98913103072135763429'}}
# {'country': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q159'}, 'hdindex': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '0.822'}, 'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '146804372'}, 'totalCityPopulation': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '2097531'}, 'countryLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Russia'}, 'continentLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Asia'}, 'ratio': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '69.98913103072135763429'}}
# {'country': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q1005'}, 'hdindex': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '0.5'}, 'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '2213889'}, 'totalCityPopulation': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '31356'}, 'countryLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'The Gambia'}, 'continentLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Africa'}, 'ratio': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '70.6049559892843474933'}}
# {'country': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q39'}, 'hdindex': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '0.962'}, 'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '8466017'}, 'totalCityPopulation': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '96345'}, 'countryLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Switzerland'}, 'continentLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Europe'}, 'ratio': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '87.87188748767450308786'}}
# {'country': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q212'}, 'hdindex': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '0.773'}, 'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '41588354'}, 'totalCityPopulation': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '388154'}, 'countryLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Ukraine'}, 'continentLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Europe'}, 'ratio': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '107.14395317322506015654'}}
# {'country': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q45'}, 'hdindex': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '0.866'}, 'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '10347892'}, 'totalCityPopulation': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '83401'}, 'countryLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Portugal'}, 'continentLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Europe'}, 'ratio': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '124.07395594777041042673'}}
# {'country': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q407199'}, 'hdindex': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '0.645'}, 'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '4550000'}, 'totalCityPopulation': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '19197'}, 'countryLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Palestinian territories'}, 'continentLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Asia'}, 'ratio': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '237.01620044798666458301'}}
# {'country': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q252'}, 'hdindex': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '0.705'}, 'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '275439000'}, 'totalCityPopulation': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '841902'}, 'countryLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Indonesia'}, 'continentLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Asia'}, 'ratio': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '327.162781416364374951'}}
# {'country': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q252'}, 'hdindex': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '0.705'}, 'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '275439000'}, 'totalCityPopulation': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '841902'}, 'countryLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Indonesia'}, 'continentLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Insular Oceania'}, 'ratio': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '327.162781416364374951'}}
# {'country': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q794'}, 'hdindex': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '0.774'}, 'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '86758304'}, 'totalCityPopulation': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '54178'}, 'countryLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Iran'}, 'continentLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Asia'}, 'ratio': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '1601.35671305696038982613'}}
# {'country': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q928'}, 'hdindex': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '0.699'}, 'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '109035343'}, 'totalCityPopulation': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '61432'}, 'countryLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Philippines'}, 'continentLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Asia'}, 'ratio': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '1774.89489191300950644615'}}

# %%
results
# Out:
# {'head': {'vars': ['country',
#    'countryLabel',
#    'continentLabel',
#    'population',
#    'hdindex',
#    'totalCityPopulation',
#    'ratio']},
#  'results': {'bindings': [{'country': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q977'},
#     'hdindex': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '0.509'},
#     'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '956985'},
#     'totalCityPopulation': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '2863922'},
#     'countryLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Djibouti'},
#     'continentLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Africa'},
#     'ratio': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '0.33415190776843782757'}},
#    {'country': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q1039'},
#     'hdindex': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '0.618'},
#     'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '204327'},
#     'totalCityPopulation': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '391964'},
#     'countryLabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'São Tomé and Príncipe'},
#     'continentLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Africa'},
#     'ratio': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '0.52129022053045687869'}},
#    {'country': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q664'},
#     'hdindex': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '0.937'},
#     'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '5118700'},
#     'totalCityPopulation': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '7145560'},
#     'countryLabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'New Zealand'},
#     'continentLabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Insular Oceania'},
#     'ratio': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '0.71634693432005329183'}},
#    {'country': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q878'},
#     'hdindex': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '0.911'},
#     'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '9890400'},
#     'totalCityPopulation': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '12009189'},
#     'countryLabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'United Arab Emirates'},
#     'continentLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Asia'},
#     'ratio': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '0.82356935176888297786'}},
#    {'country': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q221'},
#     'hdindex': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '0.77'},
#     'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '1836713'},
#     'totalCityPopulation': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '2051544'},
#     'countryLabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'North Macedonia'},
#     'continentLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Europe'},
#     'ratio': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '0.89528325982772000016'}},
#    {'country': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q1011'},
#     'hdindex': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '0.662'},
#     'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '555988'},
#     'totalCityPopulation': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '556778'},
#     'countryLabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Cape Verde'},
#     'continentLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Africa'},
#     'ratio': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '0.99858112209893350671'}},
#    {'country': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q334'},
#     'hdindex': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '0.939'},
#     'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '5866139'},
#     'totalCityPopulation': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '5866139'},
#     'countryLabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Singapore'},
#     'continentLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Asia'},
#     'ratio': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '1'}},
#    {'country': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q25279'},
#     'hdindex': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '0.89'},
#     'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '160337'},
#     'totalCityPopulation': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '150000'},
#     'countryLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Curaçao'},
#     'continentLabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'South America'},
#     'ratio': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '1.06891333333333333333'}},
#    {'country': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q408'},
#     'hdindex': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '0.951'},
#     'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '24511800'},
#     'totalCityPopulation': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '20035891'},
#     'countryLabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Australia'},
#     'continentLabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Insular Oceania'},
#     'ratio': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '1.2233945572972023056'}},
#    {'country': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q778'},
#     'hdindex': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '0.812'},
#     'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '395361'},
#     'totalCityPopulation': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '320345'},
#     'countryLabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'The Bahamas'},
#     'continentLabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'North America'},
#     'ratio': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '1.23417253273814169099'}},
#    {'country': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q717'},
#     'hdindex': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '0.691'},
#     'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '28515829'},
#     'totalCityPopulation': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '22409286'},
#     'countryLabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Venezuela'},
#     'continentLabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'South America'},
#     'ratio': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '1.27250056070505771581'}},
#    {'country': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q1007'},
#     'hdindex': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '0.483'},
#     'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '1861283'},
#     'totalCityPopulation': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '1446859'},
#     'countryLabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Guinea-Bissau'},
#     'continentLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Africa'},
#     'ratio': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '1.28643012207823982848'}},
#    {'country': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q189'},
#     'hdindex': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '0.959'},
#     'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '364260'},
#     'totalCityPopulation': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '281711'},
#     'countryLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Iceland'},
#     'continentLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Europe'},
#     'ratio': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '1.29302725133203886252'}},
#    {'country': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q711'},
#     'hdindex': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '0.739'},
#     'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '3075647'},
#     'totalCityPopulation': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '2370308'},
#     'countryLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Mongolia'},
#     'continentLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Asia'},
#     'ratio': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '1.29757272050720834592'}},
#    {'country': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q865'},
#     'hdindex': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '0.911'},
#     'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '23593794'},
#     'totalCityPopulation': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '18115941'},
#     'countryLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Taiwan'},
#     'continentLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Asia'},
#     'ratio': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '1.30237750277504215762'}},
#    {'country': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q781'},
#     'hdindex': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '0.788'},
#     'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '95425'},
#     'totalCityPopulation': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '70123'},
#     'countryLabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Antigua and Barbuda'},
#     'continentLabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'North America'},
#     'ratio': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '1.36082312508021619155'}},
#    {'country': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q810'},
#     'hdindex': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '0.72'},
#     'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '10428241'},
#     'totalCityPopulation': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '7634215'},
#     'countryLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Jordan'},
#     'continentLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Asia'},
#     'ratio': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '1.36598733465064842947'}},
#    {'country': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q801'},
#     'hdindex': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '0.919'},
#     'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '9187000'},
#     'totalCityPopulation': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '6557641'},
#     'countryLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Israel'},
#     'continentLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Asia'},
#     'ratio': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '1.40096110781300775691'}},
#    {'country': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q33'},
#     'hdindex': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '0.94'},
#     'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '5516224'},
#     'totalCityPopulation': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '3889389'},
#     'countryLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Finland'},
#     'continentLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Europe'},
#     'ratio': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '1.4182752098080186888'}},
#    {'country': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q983'},
#     'hdindex': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '0.596'},
#     'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '1267689'},
#     'totalCityPopulation': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '888148'},
#     'countryLabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Equatorial Guinea'},
#     'continentLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Africa'},
#     'ratio': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '1.42733981273391371708'}},
#    {'country': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q77'},
#     'hdindex': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '0.809'},
#     'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '3456750'},
#     'totalCityPopulation': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '2376896'},
#     'countryLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Uruguay'},
#     'continentLabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'South America'},
#     'ratio': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '1.45431268343251029915'}},
#    {'country': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q419'},
#     'hdindex': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '0.762'},
#     'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '29381884'},
#     'totalCityPopulation': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '19219901'},
#     'countryLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Peru'},
#     'continentLabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'South America'},
#     'ratio': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '1.52872192213685179752'}},
#    {'country': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q37'},
#     'hdindex': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '0.875'},
#     'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '2790842'},
#     'totalCityPopulation': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '1817374'},
#     'countryLabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Lithuania'},
#     'continentLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Europe'},
#     'ratio': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '1.53564538724555319929'}},
#    {'country': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q817'},
#     'hdindex': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '0.831'},
#     'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '4600000'},
#     'totalCityPopulation': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '2989000'},
#     'countryLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Kuwait'},
#     'continentLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Asia'},
#     'ratio': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '1.53897624623619939779'}},
#    {'country': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q750'},
#     'hdindex': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '0.692'},
#     'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '11051600'},
#     'totalCityPopulation': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '6588012'},
#     'countryLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Bolivia'},
#     'continentLabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'South America'},
#     'ratio': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '1.67753185634755977979'}},
#    {'country': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q230'},
#     'hdindex': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '0.802'},
#     'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '3717100'},
#     'totalCityPopulation': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '2196069.605'},
#     'countryLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Georgia'},
#     'continentLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Europe'},
#     'ratio': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '1.69261483859023676073'}},
#    {'country': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q230'},
#     'hdindex': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '0.802'},
#     'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '3717100'},
#     'totalCityPopulation': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '2196069.605'},
#     'countryLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Georgia'},
#     'continentLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Asia'},
#     'ratio': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '1.69261483859023676073'}},
#    {'country': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q710'},
#     'hdindex': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '0.624'},
#     'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '119438'},
#     'totalCityPopulation': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '69512'},
#     'countryLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Kiribati'},
#     'continentLabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Insular Oceania'},
#     'ratio': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '1.71823570031073771435'}},
#    {'country': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q236'},
#     'hdindex': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '0.832'},
#     'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '622359'},
#     'totalCityPopulation': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '359308'},
#     'countryLabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Montenegro'},
#     'continentLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Europe'},
#     'ratio': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '1.73210448974139178643'}},
#    {'country': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q222'},
#     'hdindex': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '0.796'},
#     'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '2793592'},
#     'totalCityPopulation': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '1544726'},
#     'countryLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Albania'},
#     'continentLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Europe'},
#     'ratio': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '1.80847088739362191094'}},
#    {'country': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q32'},
#     'hdindex': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '0.93'},
#     'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '645397'},
#     'totalCityPopulation': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '348346'},
#     'countryLabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Luxembourg'},
#     'continentLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Europe'},
#     'ratio': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '1.85274698144947839217'}},
#    {'country': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q217'},
#     'hdindex': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '0.767'},
#     'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '2550900'},
#     'totalCityPopulation': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '1372143'},
#     'countryLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Moldova'},
#     'continentLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Europe'},
#     'ratio': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '1.8590627944755029177'}},
#    {'country': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q232'},
#     'hdindex': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '0.811'},
#     'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '18276500'},
#     'totalCityPopulation': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '9800394'},
#     'countryLabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Kazakhstan'},
#     'continentLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Europe'},
#     'ratio': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '1.86487400404514349117'}},
#    {'country': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q232'},
#     'hdindex': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '0.811'},
#     'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '18276500'},
#     'totalCityPopulation': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '9800394'},
#     'countryLabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Kazakhstan'},
#     'continentLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Asia'},
#     'ratio': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '1.86487400404514349117'}},
#    {'country': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q971'},
#     'hdindex': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '0.571'},
#     'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '5260750'},
#     'totalCityPopulation': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '2733459'},
#     'countryLabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Republic of the Congo'},
#     'continentLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Africa'},
#     'ratio': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '1.92457615058429630735'}},
#    {'country': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q672'},
#     'hdindex': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '0.641'},
#     'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '11792'},
#     'totalCityPopulation': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '6025'},
#     'countryLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Tuvalu'},
#     'continentLabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Insular Oceania'},
#     'ratio': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '1.95717842323651452282'}},
#    {'country': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q786'},
#     'hdindex': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '0.767'},
#     'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '10403761'},
#     'totalCityPopulation': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '5312560'},
#     'countryLabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Dominican Republic'},
#     'continentLabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'North America'},
#     'ratio': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '1.95833289412260755643'}},
#    {'country': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q858'},
#     'hdindex': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '0.577'},
#     'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '18499181'},
#     'totalCityPopulation': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '8931980'},
#     'countryLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Syria'},
#     'continentLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Asia'},
#     'ratio': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '2.07111760214420542814'}},
#    {'country': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q43'},
#     'hdindex': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '0.838'},
#     'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '84680273'},
#     'totalCityPopulation': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '40725414.408'},
#     'countryLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Turkey'},
#     'continentLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Europe'},
#     'ratio': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '2.07929800668561437515'}},
#    {'country': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q43'},
#     'hdindex': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '0.838'},
#     'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '84680273'},
#     'totalCityPopulation': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '40725414.408'},
#     'countryLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Turkey'},
#     'continentLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Asia'},
#     'ratio': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '2.07929800668561437515'}},
#    {'country': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q784'},
#     'hdindex': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '0.72'},
#     'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '73925'},
#     'totalCityPopulation': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '34940'},
#     'countryLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Dominica'},
#     'continentLabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'North America'},
#     'ratio': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '2.11576989124212936463'}},
#    {'country': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q1016'},
#     'hdindex': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '0.718'},
#     'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '6678567'},
#     'totalCityPopulation': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '3065287'},
#     'countryLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Libya'},
#     'continentLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Africa'},
#     'ratio': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '2.17877379834253693047'}},
#    {'country': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q695'},
#     'hdindex': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '0.767'},
#     'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '21729'},
#     'totalCityPopulation': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '9935'},
#     'countryLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Palau'},
#     'continentLabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Insular Oceania'},
#     'ratio': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '2.18711625566180171112'}},
#    {'country': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q783'},
#     'hdindex': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '0.621'},
#     'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '9265067'},
#     'totalCityPopulation': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '4222399.794'},
#     'countryLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Honduras'},
#     'continentLabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'North America'},
#     'ratio': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '2.19426569060693734962'}},
#    {'country': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q241'},
#     'hdindex': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '0.764'},
#     'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '11181595'},
#     'totalCityPopulation': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '5073957'},
#     'countryLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Cuba'},
#     'continentLabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'North America'},
#     'ratio': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '2.20372285378058978427'}},
#    {'country': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q16'},
#     'hdindex': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '0.936'},
#     'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '36991981'},
#     'totalCityPopulation': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '15409859'},
#     'countryLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Canada'},
#     'continentLabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'North America'},
#     'ratio': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '2.40053987515395176555'}},
#    {'country': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q215'},
#     'hdindex': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '0.918'},
#     'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '2066880'},
#     'totalCityPopulation': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '853954'},
#     'countryLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Slovenia'},
#     'continentLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Europe'},
#     'ratio': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '2.42036456296240781119'}},
#    {'country': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q730'},
#     'hdindex': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '0.73'},
#     'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '563402'},
#     'totalCityPopulation': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '229257'},
#     'countryLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Suriname'},
#     'continentLabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'South America'},
#     'ratio': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '2.45751274770236023328'}},
#    {'country': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q766'},
#     'hdindex': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '0.709'},
#     'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '2890299'},
#     'totalCityPopulation': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '1141944'},
#     'countryLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Jamaica'},
#     'continentLabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'North America'},
#     'ratio': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '2.53103392110296126605'}},
#    {'country': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q1000'},
#     'hdindex': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '0.706'},
#     'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '2025137'},
#     'totalCityPopulation': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '797003'},
#     'countryLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Gabon'},
#     'continentLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Africa'},
#     'ratio': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '2.54094024740182910227'}},
#    {'country': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q403'},
#     'hdindex': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '0.802'},
#     'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '7022268'},
#     'totalCityPopulation': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '2752173'},
#     'countryLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Serbia'},
#     'continentLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Europe'},
#     'ratio': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '2.5515358227843961844'}},
#    {'country': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q414'},
#     'hdindex': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '0.842'},
#     'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '47327407'},
#     'totalCityPopulation': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '18536206'},
#     'countryLabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Argentina'},
#     'continentLabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'South America'},
#     'ratio': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '2.55324131594135283132'}},
#    {'country': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q760'},
#     'hdindex': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '0.715'},
#     'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '178844'},
#     'totalCityPopulation': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '70000'},
#     'countryLabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Saint Lucia'},
#     'continentLabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'North America'},
#     'ratio': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '2.55491428571428571429'}},
#    {'country': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q244'},
#     'hdindex': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '0.79'},
#     'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '285719'},
#     'totalCityPopulation': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '110000'},
#     'countryLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Barbados'},
#     'continentLabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'North America'},
#     'ratio': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '2.59744545454545454545'}},
#    {'country': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q736'},
#     'hdindex': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '0.74'},
#     'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '18000062'},
#     'totalCityPopulation': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '6844212'},
#     'countryLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Ecuador'},
#     'continentLabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'South America'},
#     'ratio': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '2.6299685047745452654'}},
#    {'country': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q1050'},
#     'hdindex': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '0.597'},
#     'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '1124753'},
#     'totalCityPopulation': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '426106'},
#     'countryLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Eswatini'},
#     'continentLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Africa'},
#     'ratio': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '2.63960845423439238124'}},
#    {'country': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q20'},
#     'hdindex': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '0.961'},
#     'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '5425270'},
#     'totalCityPopulation': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '2011592'},
#     'countryLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Norway'},
#     'continentLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Europe'},
#     'ratio': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '2.69700316962883129382'}},
#    {'country': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q986'},
#     'hdindex': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '0.492'},
#     'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '3497000'},
#     'totalCityPopulation': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '1287797'},
#     'countryLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Eritrea'},
#     'continentLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Africa'},
#     'ratio': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '2.71549009665343217914'}},
#    {'country': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q874'},
#     'hdindex': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '0.745'},
#     'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '5850901'},
#     'totalCityPopulation': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '2141264'},
#     'countryLabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Turkmenistan'},
#     'continentLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Asia'},
#     'ratio': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '2.73245195361244573299'}},
#    {'country': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q804'},
#     'hdindex': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '0.805'},
#     'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '4098587'},
#     'totalCityPopulation': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '1479264'},
#     'countryLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Panama'},
#     'continentLabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'South America'},
#     'ratio': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '2.77069339887944274991'}},
#    {'country': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q804'},
#     'hdindex': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '0.805'},
#     'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '4098587'},
#     'totalCityPopulation': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '1479264'},
#     'countryLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Panama'},
#     'continentLabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'North America'},
#     'ratio': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '2.77069339887944274991'}},
#    {'country': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q884'},
#     'hdindex': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '0.925'},
#     'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '51466201'},
#     'totalCityPopulation': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '18294978'},
#     'countryLabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'South Korea'},
#     'continentLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Asia'},
#     'ratio': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '2.81313270778461717746'}},
#    {'country': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q145'},
#     'hdindex': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '0.929'},
#     'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '66022273'},
# ...
#      'value': 'http://www.wikidata.org/entity/Q1037'},
#     'hdindex': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '0.534'},
#     'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '12208407'},
#     'totalCityPopulation': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '487080'},
#     'countryLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Rwanda'},
#     'continentLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Africa'},
#     'ratio': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '25.06448016752894801675'}},
#    {'country': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q142'},
#     'hdindex': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '0.903'},
#     'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '67063703'},
#     'totalCityPopulation': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '2520211'},
#     'countryLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'France'},
#     'continentLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Europe'},
#     'ratio': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '26.61035246651966839284'}},
#    {'country': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q846'},
#     'hdindex': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '0.855'},
#     'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '2639211'},
#     'totalCityPopulation': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '87970'},
#     'countryLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Qatar'},
#     'continentLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Asia'},
#     'ratio': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '30.00126179379333863817'}},
#    {'country': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q115'},
#     'hdindex': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '0.498'},
#     'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '104957438'},
#     'totalCityPopulation': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '3158391'},
#     'countryLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Ethiopia'},
#     'continentLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Africa'},
#     'ratio': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '33.23129973458004407941'}},
#    {'country': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q229'},
#     'hdindex': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '0.896'},
#     'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '1141166'},
#     'totalCityPopulation': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '33207'},
#     'countryLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Cyprus'},
#     'continentLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Europe'},
#     'ratio': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '34.36522419971692715391'}},
#    {'country': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q229'},
#     'hdindex': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '0.896'},
#     'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '1141166'},
#     'totalCityPopulation': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '33207'},
#     'countryLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Cyprus'},
#     'continentLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Asia'},
#     'ratio': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '34.36522419971692715391'}},
#    {'country': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q17'},
#     'hdindex': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '0.925'},
#     'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '125440000'},
#     'totalCityPopulation': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '3096335'},
#     'countryLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Japan'},
#     'continentLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Asia'},
#     'ratio': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '40.51241225513389216606'}},
#    {'country': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q1019'},
#     'hdindex': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '0.501'},
#     'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '25570895'},
#     'totalCityPopulation': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '580888'},
#     'countryLabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Madagascar'},
#     'continentLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Africa'},
#     'ratio': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '44.02035332112214402776'}},
#    {'country': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q691'},
#     'hdindex': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '0.558'},
#     'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '8935000'},
#     'totalCityPopulation': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '198632'},
#     'countryLabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Papua New Guinea'},
#     'continentLabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Insular Oceania'},
#     'ratio': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '44.98268154174553949011'}},
#    {'country': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q948'},
#     'hdindex': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '0.731'},
#     'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '11565204'},
#     'totalCityPopulation': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '171627'},
#     'countryLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Tunisia'},
#     'continentLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Africa'},
#     'ratio': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '67.38569106259504623398'}},
#    {'country': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q159'},
#     'hdindex': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '0.822'},
#     'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '146804372'},
#     'totalCityPopulation': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '2097531'},
#     'countryLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Russia'},
#     'continentLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Europe'},
#     'ratio': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '69.98913103072135763429'}},
#    {'country': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q159'},
#     'hdindex': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '0.822'},
#     'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '146804372'},
#     'totalCityPopulation': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '2097531'},
#     'countryLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Russia'},
#     'continentLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Asia'},
#     'ratio': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '69.98913103072135763429'}},
#    {'country': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q1005'},
#     'hdindex': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '0.5'},
#     'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '2213889'},
#     'totalCityPopulation': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '31356'},
#     'countryLabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'The Gambia'},
#     'continentLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Africa'},
#     'ratio': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '70.6049559892843474933'}},
#    {'country': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q39'},
#     'hdindex': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '0.962'},
#     'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '8466017'},
#     'totalCityPopulation': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '96345'},
#     'countryLabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Switzerland'},
#     'continentLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Europe'},
#     'ratio': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '87.87188748767450308786'}},
#    {'country': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q212'},
#     'hdindex': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '0.773'},
#     'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '41588354'},
#     'totalCityPopulation': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '388154'},
#     'countryLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Ukraine'},
#     'continentLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Europe'},
#     'ratio': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '107.14395317322506015654'}},
#    {'country': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q45'},
#     'hdindex': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '0.866'},
#     'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '10347892'},
#     'totalCityPopulation': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '83401'},
#     'countryLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Portugal'},
#     'continentLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Europe'},
#     'ratio': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '124.07395594777041042673'}},
#    {'country': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q407199'},
#     'hdindex': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '0.645'},
#     'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '4550000'},
#     'totalCityPopulation': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '19197'},
#     'countryLabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Palestinian territories'},
#     'continentLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Asia'},
#     'ratio': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '237.01620044798666458301'}},
#    {'country': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q252'},
#     'hdindex': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '0.705'},
#     'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '275439000'},
#     'totalCityPopulation': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '841902'},
#     'countryLabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Indonesia'},
#     'continentLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Asia'},
#     'ratio': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '327.162781416364374951'}},
#    {'country': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q252'},
#     'hdindex': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '0.705'},
#     'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '275439000'},
#     'totalCityPopulation': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '841902'},
#     'countryLabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Indonesia'},
#     'continentLabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Insular Oceania'},
#     'ratio': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '327.162781416364374951'}},
#    {'country': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q794'},
#     'hdindex': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '0.774'},
#     'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '86758304'},
#     'totalCityPopulation': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '54178'},
#     'countryLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Iran'},
#     'continentLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Asia'},
#     'ratio': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '1601.35671305696038982613'}},
#    {'country': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q928'},
#     'hdindex': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '0.699'},
#     'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '109035343'},
#     'totalCityPopulation': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '61432'},
#     'countryLabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Philippines'},
#     'continentLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Asia'},
#     'ratio': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '1774.89489191300950644615'}}]}}

# %%
data = [{"country" : x["countryLabel"]["value"],"continent" : x["continentLabel"]["value"],"totalCityPopulation" : round(float(x["totalCityPopulation"]["value"])), "population" : int(x["population"]["value"]), "ratio" : round(float(x["ratio"]["value"]),1)} for x in results["results"]["bindings"]]
data
# Out:
# [{'country': 'Djibouti',
#   'continent': 'Africa',
#   'totalCityPopulation': 2863922,
#   'population': 956985,
#   'ratio': 0.3},
#  {'country': 'São Tomé and Príncipe',
#   'continent': 'Africa',
#   'totalCityPopulation': 391964,
#   'population': 204327,
#   'ratio': 0.5},
#  {'country': 'New Zealand',
#   'continent': 'Insular Oceania',
#   'totalCityPopulation': 7145560,
#   'population': 5118700,
#   'ratio': 0.7},
#  {'country': 'United Arab Emirates',
#   'continent': 'Asia',
#   'totalCityPopulation': 12009189,
#   'population': 9890400,
#   'ratio': 0.8},
#  {'country': 'North Macedonia',
#   'continent': 'Europe',
#   'totalCityPopulation': 2051544,
#   'population': 1836713,
#   'ratio': 0.9},
#  {'country': 'Cape Verde',
#   'continent': 'Africa',
#   'totalCityPopulation': 556778,
#   'population': 555988,
#   'ratio': 1.0},
#  {'country': 'Singapore',
#   'continent': 'Asia',
#   'totalCityPopulation': 5866139,
#   'population': 5866139,
#   'ratio': 1.0},
#  {'country': 'Curaçao',
#   'continent': 'South America',
#   'totalCityPopulation': 150000,
#   'population': 160337,
#   'ratio': 1.1},
#  {'country': 'Australia',
#   'continent': 'Insular Oceania',
#   'totalCityPopulation': 20035891,
#   'population': 24511800,
#   'ratio': 1.2},
#  {'country': 'The Bahamas',
#   'continent': 'North America',
#   'totalCityPopulation': 320345,
#   'population': 395361,
#   'ratio': 1.2},
#  {'country': 'Venezuela',
#   'continent': 'South America',
#   'totalCityPopulation': 22409286,
#   'population': 28515829,
#   'ratio': 1.3},
#  {'country': 'Guinea-Bissau',
#   'continent': 'Africa',
#   'totalCityPopulation': 1446859,
#   'population': 1861283,
#   'ratio': 1.3},
#  {'country': 'Iceland',
#   'continent': 'Europe',
#   'totalCityPopulation': 281711,
#   'population': 364260,
#   'ratio': 1.3},
#  {'country': 'Mongolia',
#   'continent': 'Asia',
#   'totalCityPopulation': 2370308,
#   'population': 3075647,
#   'ratio': 1.3},
#  {'country': 'Taiwan',
#   'continent': 'Asia',
#   'totalCityPopulation': 18115941,
#   'population': 23593794,
#   'ratio': 1.3},
#  {'country': 'Antigua and Barbuda',
#   'continent': 'North America',
#   'totalCityPopulation': 70123,
#   'population': 95425,
#   'ratio': 1.4},
#  {'country': 'Jordan',
#   'continent': 'Asia',
#   'totalCityPopulation': 7634215,
#   'population': 10428241,
#   'ratio': 1.4},
#  {'country': 'Israel',
#   'continent': 'Asia',
#   'totalCityPopulation': 6557641,
#   'population': 9187000,
#   'ratio': 1.4},
#  {'country': 'Finland',
#   'continent': 'Europe',
#   'totalCityPopulation': 3889389,
#   'population': 5516224,
#   'ratio': 1.4},
#  {'country': 'Equatorial Guinea',
#   'continent': 'Africa',
#   'totalCityPopulation': 888148,
#   'population': 1267689,
#   'ratio': 1.4},
#  {'country': 'Uruguay',
#   'continent': 'South America',
#   'totalCityPopulation': 2376896,
#   'population': 3456750,
#   'ratio': 1.5},
#  {'country': 'Peru',
#   'continent': 'South America',
#   'totalCityPopulation': 19219901,
#   'population': 29381884,
#   'ratio': 1.5},
#  {'country': 'Lithuania',
#   'continent': 'Europe',
#   'totalCityPopulation': 1817374,
#   'population': 2790842,
#   'ratio': 1.5},
#  {'country': 'Kuwait',
#   'continent': 'Asia',
#   'totalCityPopulation': 2989000,
#   'population': 4600000,
#   'ratio': 1.5},
#  {'country': 'Bolivia',
#   'continent': 'South America',
#   'totalCityPopulation': 6588012,
#   'population': 11051600,
#   'ratio': 1.7},
#  {'country': 'Georgia',
#   'continent': 'Europe',
#   'totalCityPopulation': 2196070,
#   'population': 3717100,
#   'ratio': 1.7},
#  {'country': 'Georgia',
#   'continent': 'Asia',
#   'totalCityPopulation': 2196070,
#   'population': 3717100,
#   'ratio': 1.7},
#  {'country': 'Kiribati',
#   'continent': 'Insular Oceania',
#   'totalCityPopulation': 69512,
#   'population': 119438,
#   'ratio': 1.7},
#  {'country': 'Montenegro',
#   'continent': 'Europe',
#   'totalCityPopulation': 359308,
#   'population': 622359,
#   'ratio': 1.7},
#  {'country': 'Albania',
#   'continent': 'Europe',
#   'totalCityPopulation': 1544726,
#   'population': 2793592,
#   'ratio': 1.8},
#  {'country': 'Luxembourg',
#   'continent': 'Europe',
#   'totalCityPopulation': 348346,
#   'population': 645397,
#   'ratio': 1.9},
#  {'country': 'Moldova',
#   'continent': 'Europe',
#   'totalCityPopulation': 1372143,
#   'population': 2550900,
#   'ratio': 1.9},
#  {'country': 'Kazakhstan',
#   'continent': 'Europe',
#   'totalCityPopulation': 9800394,
#   'population': 18276500,
#   'ratio': 1.9},
#  {'country': 'Kazakhstan',
#   'continent': 'Asia',
#   'totalCityPopulation': 9800394,
#   'population': 18276500,
#   'ratio': 1.9},
#  {'country': 'Republic of the Congo',
#   'continent': 'Africa',
#   'totalCityPopulation': 2733459,
#   'population': 5260750,
#   'ratio': 1.9},
#  {'country': 'Tuvalu',
#   'continent': 'Insular Oceania',
#   'totalCityPopulation': 6025,
#   'population': 11792,
#   'ratio': 2.0},
#  {'country': 'Dominican Republic',
#   'continent': 'North America',
#   'totalCityPopulation': 5312560,
#   'population': 10403761,
#   'ratio': 2.0},
#  {'country': 'Syria',
#   'continent': 'Asia',
#   'totalCityPopulation': 8931980,
#   'population': 18499181,
#   'ratio': 2.1},
#  {'country': 'Turkey',
#   'continent': 'Europe',
#   'totalCityPopulation': 40725414,
#   'population': 84680273,
#   'ratio': 2.1},
#  {'country': 'Turkey',
#   'continent': 'Asia',
#   'totalCityPopulation': 40725414,
#   'population': 84680273,
#   'ratio': 2.1},
#  {'country': 'Dominica',
#   'continent': 'North America',
#   'totalCityPopulation': 34940,
#   'population': 73925,
#   'ratio': 2.1},
#  {'country': 'Libya',
#   'continent': 'Africa',
#   'totalCityPopulation': 3065287,
#   'population': 6678567,
#   'ratio': 2.2},
#  {'country': 'Palau',
#   'continent': 'Insular Oceania',
#   'totalCityPopulation': 9935,
#   'population': 21729,
#   'ratio': 2.2},
#  {'country': 'Honduras',
#   'continent': 'North America',
#   'totalCityPopulation': 4222400,
#   'population': 9265067,
#   'ratio': 2.2},
#  {'country': 'Cuba',
#   'continent': 'North America',
#   'totalCityPopulation': 5073957,
#   'population': 11181595,
#   'ratio': 2.2},
#  {'country': 'Canada',
#   'continent': 'North America',
#   'totalCityPopulation': 15409859,
#   'population': 36991981,
#   'ratio': 2.4},
#  {'country': 'Slovenia',
#   'continent': 'Europe',
#   'totalCityPopulation': 853954,
#   'population': 2066880,
#   'ratio': 2.4},
#  {'country': 'Suriname',
#   'continent': 'South America',
#   'totalCityPopulation': 229257,
#   'population': 563402,
#   'ratio': 2.5},
#  {'country': 'Jamaica',
#   'continent': 'North America',
#   'totalCityPopulation': 1141944,
#   'population': 2890299,
#   'ratio': 2.5},
#  {'country': 'Gabon',
#   'continent': 'Africa',
#   'totalCityPopulation': 797003,
#   'population': 2025137,
#   'ratio': 2.5},
#  {'country': 'Serbia',
#   'continent': 'Europe',
#   'totalCityPopulation': 2752173,
#   'population': 7022268,
#   'ratio': 2.6},
#  {'country': 'Argentina',
#   'continent': 'South America',
#   'totalCityPopulation': 18536206,
#   'population': 47327407,
#   'ratio': 2.6},
#  {'country': 'Saint Lucia',
#   'continent': 'North America',
#   'totalCityPopulation': 70000,
#   'population': 178844,
#   'ratio': 2.6},
#  {'country': 'Barbados',
#   'continent': 'North America',
#   'totalCityPopulation': 110000,
#   'population': 285719,
#   'ratio': 2.6},
#  {'country': 'Ecuador',
#   'continent': 'South America',
#   'totalCityPopulation': 6844212,
#   'population': 18000062,
#   'ratio': 2.6},
#  {'country': 'Eswatini',
#   'continent': 'Africa',
#   'totalCityPopulation': 426106,
#   'population': 1124753,
#   'ratio': 2.6},
#  {'country': 'Norway',
#   'continent': 'Europe',
#   'totalCityPopulation': 2011592,
#   'population': 5425270,
#   'ratio': 2.7},
#  {'country': 'Eritrea',
#   'continent': 'Africa',
#   'totalCityPopulation': 1287797,
#   'population': 3497000,
#   'ratio': 2.7},
#  {'country': 'Turkmenistan',
#   'continent': 'Asia',
#   'totalCityPopulation': 2141264,
#   'population': 5850901,
#   'ratio': 2.7},
#  {'country': 'Panama',
#   'continent': 'South America',
#   'totalCityPopulation': 1479264,
#   'population': 4098587,
#   'ratio': 2.8},
#  {'country': 'Panama',
#   'continent': 'North America',
#   'totalCityPopulation': 1479264,
#   'population': 4098587,
#   'ratio': 2.8},
#  {'country': 'South Korea',
#   'continent': 'Asia',
#   'totalCityPopulation': 18294978,
#   'population': 51466201,
#   'ratio': 2.8},
#  {'country': 'United Kingdom',
#   'continent': 'Europe',
#   'totalCityPopulation': 23418603,
#   'population': 66022273,
#   'ratio': 2.8},
#  {'country': 'State of Palestine',
#   'continent': 'Asia',
#   'totalCityPopulation': 1852745,
#   'population': 5227193,
#   'ratio': 2.8},
#  {'country': 'Egypt',
#   'continent': 'Africa',
#   'totalCityPopulation': 33411500,
#   'population': 94798827,
#   'ratio': 2.8},
#  {'country': 'Egypt',
#   'continent': 'Asia',
#   'totalCityPopulation': 33411500,
#   'population': 94798827,
#   'ratio': 2.8},
#  {'country': 'Mexico',
#   'continent': 'North America',
#   'totalCityPopulation': 43648437,
#   'population': 124777324,
#   'ratio': 2.9},
#  {'country': 'Togo',
#   'continent': 'Africa',
#   'totalCityPopulation': 2719117,
#   'population': 7797694,
#   'ratio': 2.9},
#  {'country': 'Guyana',
#   'continent': 'South America',
#   'totalCityPopulation': 265653,
#   'population': 777859,
#   'ratio': 2.9},
#  {'country': 'Spain',
#   'continent': 'Europe',
#   'totalCityPopulation': 15931262,
#   'population': 46733038,
#   'ratio': 2.9},
#  {'country': 'Belize',
#   'continent': 'North America',
#   'totalCityPopulation': 126057,
#   'population': 374681,
#   'ratio': 3.0},
#  {'country': 'Central African Republic',
#   'continent': 'Africa',
#   'totalCityPopulation': 1491450,
#   'population': 4659080,
#   'ratio': 3.1},
#  {'country': 'Bosnia and Herzegovina',
#   'continent': 'Europe',
#   'totalCityPopulation': 1107658,
#   'population': 3507017,
#   'ratio': 3.2},
#  {'country': 'Iraq',
#   'continent': 'Asia',
#   'totalCityPopulation': 12006005,
#   'population': 38274618,
#   'ratio': 3.2},
#  {'country': 'Greece',
#   'continent': 'Europe',
#   'totalCityPopulation': 3269665,
#   'population': 10432481,
#   'ratio': 3.2},
#  {'country': 'Angola',
#   'continent': 'Africa',
#   'totalCityPopulation': 10222219,
#   'population': 32866270,
#   'ratio': 3.2},
#  {'country': 'Poland',
#   'continent': 'Europe',
#   'totalCityPopulation': 11907442,
#   'population': 38382576,
#   'ratio': 3.2},
#  {'country': 'Lesotho',
#   'continent': 'Africa',
#   'totalCityPopulation': 690592,
#   'population': 2233339,
#   'ratio': 3.2},
#  {'country': 'Maldives',
#   'continent': 'Asia',
#   'totalCityPopulation': 133019,
#   'population': 436330,
#   'ratio': 3.3},
#  {'country': 'Bahrain',
#   'continent': 'Asia',
#   'totalCityPopulation': 446740,
#   'population': 1492584,
#   'ratio': 3.3},
#  {'country': 'Sudan',
#   'continent': 'Africa',
#   'totalCityPopulation': 11651992,
#   'population': 40533330,
#   'ratio': 3.5},
#  {'country': 'Paraguay',
#   'continent': 'South America',
#   'totalCityPopulation': 1941268,
#   'population': 6811297,
#   'ratio': 3.5},
#  {'country': 'Andorra',
#   'continent': 'Europe',
#   'totalCityPopulation': 22151,
#   'population': 78151,
#   'ratio': 3.5},
#  {'country': 'Ghana',
#   'continent': 'Africa',
#   'totalCityPopulation': 7506988,
#   'population': 26908262,
#   'ratio': 3.6},
#  {'country': 'Malawi',
#   'continent': 'Africa',
#   'totalCityPopulation': 5172737,
#   'population': 18622104,
#   'ratio': 3.6},
#  {'country': 'Seychelles',
#   'continent': 'Africa',
#   'totalCityPopulation': 26450,
#   'population': 95843,
#   'ratio': 3.6},
#  {'country': 'Mauritania',
#   'continent': 'Africa',
#   'totalCityPopulation': 1219190,
#   'population': 4420184,
#   'ratio': 3.6},
#  {'country': 'Zambia',
#   'continent': 'Africa',
#   'totalCityPopulation': 4628097,
#   'population': 17094130,
#   'ratio': 3.7},
#  {'country': 'Guatemala',
#   'continent': 'North America',
#   'totalCityPopulation': 4665034,
#   'population': 17263239,
#   'ratio': 3.7},
#  {'country': 'Sierra Leone',
#   'continent': 'Africa',
#   'totalCityPopulation': 1972489,
#   'population': 7557212,
#   'ratio': 3.8},
#  {'country': 'Morocco',
#   'continent': 'Africa',
#   'totalCityPopulation': 9386480,
#   'population': 36029138,
#   'ratio': 3.8},
#  {'country': 'Vietnam',
#   'continent': 'Asia',
#   'totalCityPopulation': 24702042,
#   'population': 96208984,
#   'ratio': 3.9},
#  {'country': 'Algeria',
#   'continent': 'Africa',
#   'totalCityPopulation': 11204723,
#   'population': 43900000,
#   'ratio': 3.9},
#  {'country': 'Slovakia',
#   'continent': 'Europe',
#   'totalCityPopulation': 1352072,
#   'population': 5449270,
#   'ratio': 4.0},
#  {'country': 'Namibia',
#   'continent': 'Africa',
#   'totalCityPopulation': 623337,
#   'population': 2533794,
#   'ratio': 4.1},
#  {'country': 'Zimbabwe',
#   'continent': 'Africa',
#   'totalCityPopulation': 3674506,
#   'population': 15178979,
#   'ratio': 4.1},
#  {'country': 'Saint Kitts and Nevis',
#   'continent': 'North America',
#   'totalCityPopulation': 13220,
#   'population': 55345,
#   'ratio': 4.2},
#  {'country': 'Ivory Coast',
#   'continent': 'Africa',
#   'totalCityPopulation': 5713209,
#   'population': 24294750,
#   'ratio': 4.3},
#  {'country': 'Democratic Republic of the Congo',
#   'continent': 'Africa',
#   'totalCityPopulation': 19852281,
#   'population': 86790567,
#   'ratio': 4.4},
#  {'country': 'Nicaragua',
#   'continent': 'North America',
#   'totalCityPopulation': 1175918,
#   'population': 5142098,
#   'ratio': 4.4},
#  {'country': 'Yemen',
#   'continent': 'Asia',
#   'totalCityPopulation': 6451175,
#   'population': 28250420,
#   'ratio': 4.4},
#  {'country': 'Saint Vincent and the Grenadines',
#   'continent': 'North America',
#   'totalCityPopulation': 25000,
#   'population': 109897,
#   'ratio': 4.4},
#  {'country': 'Netherlands',
#   'continent': 'Europe',
#   'totalCityPopulation': 3830833,
#   'population': 17282163,
#   'ratio': 4.5},
#  {'country': 'Oman',
#   'continent': 'Asia',
#   'totalCityPopulation': 1054248,
#   'population': 4829480,
#   'ratio': 4.6},
#  {'country': 'Tonga',
#   'continent': 'Insular Oceania',
#   'totalCityPopulation': 23221,
#   'population': 108020,
#   'ratio': 4.7},
#  {'country': 'Haiti',
#   'continent': 'North America',
#   'totalCityPopulation': 2331606,
#   'population': 10981229,
#   'ratio': 4.7},
#  {'country': 'Denmark',
#   'continent': 'Europe',
#   'totalCityPopulation': 1234180,
#   'population': 5827463,
#   'ratio': 4.7},
#  {'country': 'Nigeria',
#   'continent': 'Africa',
#   'totalCityPopulation': 44546724,
#   'population': 211400708,
#   'ratio': 4.7},
#  {'country': 'Mauritius',
#   'continent': 'Africa',
#   'totalCityPopulation': 266291,
#   'population': 1264613,
#   'ratio': 4.7},
#  {'country': 'Kyrgyzstan',
#   'continent': 'Asia',
#   'totalCityPopulation': 1276979,
#   'population': 6201500,
#   'ratio': 4.9},
#  {'country': 'Uzbekistan',
#   'continent': 'Asia',
#   'totalCityPopulation': 6884233,
#   'population': 33570609,
#   'ratio': 4.9},
#  {'country': 'Italy',
#   'continent': 'Europe',
#   'totalCityPopulation': 12205077,
#   'population': 60317000,
#   'ratio': 4.9},
#  {'country': 'Malaysia',
#   'continent': 'Asia',
#   'totalCityPopulation': 6545971,
#   'population': 32447385,
#   'ratio': 5.0},
#  {'country': 'Afghanistan',
#   'continent': 'Asia',
#   'totalCityPopulation': 7552810,
#   'population': 37466414,
#   'ratio': 5.0},
#  {'country': 'Laos',
#   'continent': 'Asia',
#   'totalCityPopulation': 1373097,
#   'population': 6858160,
#   'ratio': 5.0},
#  {'country': 'Vanuatu',
#   'continent': 'Insular Oceania',
#   'totalCityPopulation': 54435,
#   'population': 276244,
#   'ratio': 5.1},
#  {'country': 'Liberia',
#   'continent': 'Africa',
#   'totalCityPopulation': 1021762,
#   'population': 5214030,
#   'ratio': 5.1},
#  {'country': 'Samoa',
#   'continent': 'Insular Oceania',
#   'totalCityPopulation': 37708,
#   'population': 196440,
#   'ratio': 5.2},
#  {'country': 'Tajikistan',
#   'continent': 'Asia',
#   'totalCityPopulation': 1666500,
#   'population': 8921343,
#   'ratio': 5.4},
#  {'country': 'Myanmar',
#   'continent': 'Asia',
#   'totalCityPopulation': 9644663,
#   'population': 53370609,
#   'ratio': 5.5},
#  {'country': 'Guinea',
#   'continent': 'Africa',
#   'totalCityPopulation': 2291169,
#   'population': 12717176,
#   'ratio': 5.6},
#  {'country': 'South Africa',
#   'continent': 'Africa',
#   'totalCityPopulation': 10817593,
#   'population': 60142978,
#   'ratio': 5.6},
#  {'country': 'Colombia',
#   'continent': 'South America',
#   'totalCityPopulation': 8794014,
#   'population': 49065615,
#   'ratio': 5.6},
#  {'country': 'Uganda',
#   'continent': 'Africa',
#   'totalCityPopulation': 8425446,
#   'population': 47123531,
#   'ratio': 5.6},
#  {'country': 'Cambodia',
#   'continent': 'Asia',
#   'totalCityPopulation': 2849482,
#   'population': 16005373,
#   'ratio': 5.6},
#  {'country': 'Pakistan',
#   'continent': 'Asia',
#   'totalCityPopulation': 39600369,
#   'population': 223773700,
#   'ratio': 5.7},
#  {'country': 'Mozambique',
#   'continent': 'Africa',
#   'totalCityPopulation': 5158066,
#   'population': 29668834,
#   'ratio': 5.8},
#  {'country': 'El Salvador',
#   'continent': 'North America',
#   'totalCityPopulation': 979131,
#   'population': 5744113,
#   'ratio': 5.9},
#  {'country': 'Comoros',
#   'continent': 'Africa',
#   'totalCityPopulation': 153287,
#   'population': 902348,
#   'ratio': 5.9},
#  {'country': 'Fiji',
#   'continent': 'Insular Oceania',
#   'totalCityPopulation': 140491,
#   'population': 905502,
#   'ratio': 6.4},
#  {'country': 'Benin',
#   'continent': 'Africa',
#   'totalCityPopulation': 1612504,
#   'population': 11175692,
#   'ratio': 6.9},
#  {'country': 'Cameroon',
#   'continent': 'Africa',
#   'totalCityPopulation': 3412009,
#   'population': 24053727,
#   'ratio': 7.0},
#  {'country': 'Solomon Islands',
#   'continent': 'Insular Oceania',
#   'totalCityPopulation': 84520,
#   'population': 611343,
#   'ratio': 7.2},
#  {'country': 'Trinidad and Tobago',
#   'continent': 'North America',
#   'totalCityPopulation': 182454,
#   'population': 1369125,
#   'ratio': 7.5},
#  {'country': 'Bhutan',
#   'continent': 'Asia',
#   'totalCityPopulation': 106695,
#   'population': 807610,
#   'ratio': 7.6},
#  {'country': 'Tanzania',
#   'continent': 'Africa',
#   'totalCityPopulation': 7542500,
#   'population': 57310019,
#   'ratio': 7.6},
#  {'country': 'Azerbaijan',
#   'continent': 'Europe',
#   'totalCityPopulation': 1328019,
#   'population': 10127874,
#   'ratio': 7.6},
#  {'country': 'Azerbaijan',
#   'continent': 'Asia',
#   'totalCityPopulation': 1328019,
#   'population': 10127874,
#   'ratio': 7.6},
#  {'country': 'Croatia',
#   'continent': 'Europe',
#   'totalCityPopulation': 534665,
#   'population': 4105493,
#   'ratio': 7.7},
#  {'country': 'Sweden',
#   'continent': 'Europe',
#   'totalCityPopulation': 1348087,
#   'population': 10409248,
#   'ratio': 7.7},
#  {'country': 'South Sudan',
#   'continent': 'Africa',
#   'totalCityPopulation': 1596794,
#   'population': 12575714,
#   'ratio': 7.9},
#  {'country': 'Bangladesh',
#   'continent': 'Asia',
#   'totalCityPopulation': 20759453,
#   'population': 165775000,
#   'ratio': 8.0},
#  {'country': 'San Marino',
#   'continent': 'Europe',
#   'totalCityPopulation': 4040,
#   'population': 33400,
#   'ratio': 8.3},
#  {'country': 'Costa Rica',
#   'continent': 'North America',
#   'totalCityPopulation': 586894,
#   'population': 4905769,
#   'ratio': 8.4},
#  {'country': 'Chad',
#   'continent': 'Africa',
#   'totalCityPopulation': 1849789,
#   'population': 15477751,
#   'ratio': 8.4},
#  {'country': 'Mali',
#   'continent': 'Africa',
#   'totalCityPopulation': 2391917,
#   'population': 20250833,
#   'ratio': 8.5},
#  {'country': 'Brunei',
#   'continent': 'Asia',
#   'totalCityPopulation': 50000,
#   'population': 428697,
#   'ratio': 8.6},
#  {'country': 'Lebanon',
#   'continent': 'Asia',
#   'totalCityPopulation': 709221,
#   'population': 6100075,
#   'ratio': 8.6},
#  {'country': 'Costa Rica',
#   'continent': 'North America',
#   'totalCityPopulation': 586894,
#   'population': 5213362,
#   'ratio': 8.9},
#  {'country': 'India',
#   'continent': 'Asia',
#   'totalCityPopulation': 146779982,
#   'population': 1326093247,
#   'ratio': 9.0},
#  {'country': 'Republic of Ireland',
#   'continent': 'Europe',
#   'totalCityPopulation': 544640,
#   'population': 5123536,
#   'ratio': 9.4},
#  {'country': 'Burkina Faso',
#   'continent': 'Africa',
#   'totalCityPopulation': 2154217,
#   'population': 20488000,
#   'ratio': 9.5},
#  {'country': 'Senegal',
#   'continent': 'Africa',
#   'totalCityPopulation': 1604353,
#   'population': 15850567,
#   'ratio': 9.9},
#  {'country': "People's Republic of China",
#   'continent': 'Asia',
#   'totalCityPopulation': 136732848,
#   'population': 1443497378,
#   'ratio': 10.6},
#  {'country': 'Botswana',
#   'continent': 'Africa',
#   'totalCityPopulation': 210600,
#   'population': 2291661,
#   'ratio': 10.9},
#  {'country': 'Thailand',
#   'continent': 'Asia',
#   'totalCityPopulation': 5929467,
#   'population': 66188503,
#   'ratio': 11.2},
#  {'country': 'Czech Republic',
#   'continent': 'Europe',
#   'totalCityPopulation': 932447,
#   'population': 10516707,
#   'ratio': 11.3},
#  {'country': 'Nepal',
#   'continent': 'Asia',
#   'totalCityPopulation': 2655774,
#   'population': 30327877,
#   'ratio': 11.4},
#  {'country': 'Burundi',
#   'continent': 'Africa',
#   'totalCityPopulation': 996656,
#   'population': 11530580,
#   'ratio': 11.6},
#  {'country': 'Chile',
#   'continent': 'South America',
#   'totalCityPopulation': 1671560,
#   'population': 19458000,
#   'ratio': 11.6},
#  {'country': 'Germany',
#   'continent': 'Europe',
#   'totalCityPopulation': 6852407,
#   'population': 83149300,
#   'ratio': 12.1},
#  {'country': 'Sri Lanka',
#   'continent': 'Asia',
#   'totalCityPopulation': 1641360,
#   'population': 21444000,
#   'ratio': 13.1},
#  {'country': 'Grenada',
#   'continent': 'North America',
#   'totalCityPopulation': 8091,
#   'population': 107825,
#   'ratio': 13.3},
#  {'country': 'Brazil',
#   'continent': 'South America',
#   'totalCityPopulation': 15642318,
#   'population': 213317639,
#   'ratio': 13.6},
#  {'country': 'Niger',
#   'continent': 'Africa',
#   'totalCityPopulation': 1529702,
#   'population': 21477348,
#   'ratio': 14.0},
#  {'country': 'Belgium',
#   'continent': 'Europe',
#   'totalCityPopulation': 775758,
#   'population': 11584008,
#   'ratio': 14.9},
#  {'country': 'Kenya',
#   'continent': 'Africa',
#   'totalCityPopulation': 3146910,
#   'population': 48468138,
#   'ratio': 15.4},
#  {'country': 'Hungary',
#   'continent': 'Europe',
#   'totalCityPopulation': 614946,
#   'population': 9769526,
#   'ratio': 15.9},
#  {'country': 'Federated States of Micronesia',
#   'continent': 'Insular Oceania',
#   'totalCityPopulation': 6227,
#   'population': 105544,
#   'ratio': 16.9},
#  {'country': 'Romania',
#   'continent': 'Europe',
#   'totalCityPopulation': 1114272,
#   'population': 19586539,
#   'ratio': 17.6},
#  {'country': 'Austria',
#   'continent': 'Europe',
#   'totalCityPopulation': 510419,
#   'population': 8979894,
#   'ratio': 17.6},
#  {'country': 'Malta',
#   'continent': 'Europe',
#   'totalCityPopulation': 24356,
#   'population': 465292,
#   'ratio': 19.1},
#  {'country': 'East Timor',
#   'continent': 'Asia',
#   'totalCityPopulation': 64331,
#   'population': 1296311,
#   'ratio': 20.2},
#  {'country': 'United States of America',
#   'continent': 'North America',
#   'totalCityPopulation': 14949087,
#   'population': 331449281,
#   'ratio': 22.2},
#  {'country': 'United States of America',
#   'continent': 'Insular Oceania',
#   'totalCityPopulation': 14949087,
#   'population': 331449281,
#   'ratio': 22.2},
#  {'country': 'Armenia',
#   'continent': 'Asia',
#   'totalCityPopulation': 123683,
#   'population': 2930450,
#   'ratio': 23.7},
#  {'country': 'Saudi Arabia',
#   'continent': 'Asia',
#   'totalCityPopulation': 1344776,
#   'population': 33000000,
#   'ratio': 24.5},
#  {'country': 'Rwanda',
#   'continent': 'Africa',
#   'totalCityPopulation': 487080,
#   'population': 12208407,
#   'ratio': 25.1},
#  {'country': 'France',
#   'continent': 'Europe',
#   'totalCityPopulation': 2520211,
#   'population': 67063703,
#   'ratio': 26.6},
#  {'country': 'Qatar',
#   'continent': 'Asia',
#   'totalCityPopulation': 87970,
#   'population': 2639211,
#   'ratio': 30.0},
#  {'country': 'Ethiopia',
#   'continent': 'Africa',
#   'totalCityPopulation': 3158391,
#   'population': 104957438,
#   'ratio': 33.2},
#  {'country': 'Cyprus',
#   'continent': 'Europe',
#   'totalCityPopulation': 33207,
#   'population': 1141166,
#   'ratio': 34.4},
#  {'country': 'Cyprus',
#   'continent': 'Asia',
#   'totalCityPopulation': 33207,
#   'population': 1141166,
#   'ratio': 34.4},
#  {'country': 'Japan',
#   'continent': 'Asia',
#   'totalCityPopulation': 3096335,
#   'population': 125440000,
#   'ratio': 40.5},
#  {'country': 'Madagascar',
#   'continent': 'Africa',
#   'totalCityPopulation': 580888,
#   'population': 25570895,
#   'ratio': 44.0},
#  {'country': 'Papua New Guinea',
#   'continent': 'Insular Oceania',
#   'totalCityPopulation': 198632,
#   'population': 8935000,
#   'ratio': 45.0},
#  {'country': 'Tunisia',
#   'continent': 'Africa',
#   'totalCityPopulation': 171627,
#   'population': 11565204,
#   'ratio': 67.4},
#  {'country': 'Russia',
#   'continent': 'Europe',
#   'totalCityPopulation': 2097531,
#   'population': 146804372,
#   'ratio': 70.0},
#  {'country': 'Russia',
#   'continent': 'Asia',
#   'totalCityPopulation': 2097531,
#   'population': 146804372,
#   'ratio': 70.0},
#  {'country': 'The Gambia',
#   'continent': 'Africa',
#   'totalCityPopulation': 31356,
#   'population': 2213889,
#   'ratio': 70.6},
#  {'country': 'Switzerland',
#   'continent': 'Europe',
#   'totalCityPopulation': 96345,
#   'population': 8466017,
#   'ratio': 87.9},
#  {'country': 'Ukraine',
#   'continent': 'Europe',
#   'totalCityPopulation': 388154,
#   'population': 41588354,
#   'ratio': 107.1},
#  {'country': 'Portugal',
#   'continent': 'Europe',
#   'totalCityPopulation': 83401,
#   'population': 10347892,
#   'ratio': 124.1},
#  {'country': 'Palestinian territories',
#   'continent': 'Asia',
#   'totalCityPopulation': 19197,
#   'population': 4550000,
#   'ratio': 237.0},
#  {'country': 'Indonesia',
#   'continent': 'Asia',
#   'totalCityPopulation': 841902,
#   'population': 275439000,
#   'ratio': 327.2},
#  {'country': 'Indonesia',
#   'continent': 'Insular Oceania',
#   'totalCityPopulation': 841902,
#   'population': 275439000,
#   'ratio': 327.2},
#  {'country': 'Iran',
#   'continent': 'Asia',
#   'totalCityPopulation': 54178,
#   'population': 86758304,
#   'ratio': 1601.4},
#  {'country': 'Philippines',
#   'continent': 'Asia',
#   'totalCityPopulation': 61432,
#   'population': 109035343,
#   'ratio': 1774.9}]

# %%
pd.DataFrame(data).set_index("country").head(10).plot.barh().invert_yaxis()

# %%
maindata = pd.DataFrame(data)
maindata.head()
# Out:
#                  country        continent  totalCityPopulation  population  \
# 0               Djibouti           Africa              2863922      956985
# 1  São Tomé and Príncipe           Africa               391964      204327
# 2            New Zealand  Insular Oceania              7145560     5118700
# 3   United Arab Emirates             Asia             12009189     9890400
# 4        North Macedonia           Europe              2051544     1836713
#
#    ratio
# 0    0.3
# 1    0.5
# 2    0.7
# 3    0.8
# 4    0.9

# %%
maindata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 198 entries, 0 to 197
# Data columns (total 5 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   country              198 non-null    object
#  1   continent            198 non-null    object
#  2   totalCityPopulation  198 non-null    int64
#  3   population           198 non-null    int64
#  4   ratio                198 non-null    float64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 7.9+ KB
